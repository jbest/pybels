# %%
# Generated using Claude.ai
#https://claude.ai/chat/18fa6039-d306-449d-958b-08ad823fe977

# %%
import pandas as pd

def analyze_locations(df):
    """
    Creates location IDs and analyzes location groups.
    
    Parameters:
    df (pd.DataFrame): DataFrame with 'bels_location_string' and coordinate columns
    
    Returns:
    pd.DataFrame: DataFrame with location IDs and group statistics
    """
    # Create location IDs
    unique_locations = df['bels_location_string'].unique()
    location_to_id = {loc: idx for idx, loc in enumerate(unique_locations)}
    df['bels_location_id'] = df['bels_location_string'].map(location_to_id)
    
    # Calculate stats per location
    location_stats = df.groupby('bels_location_string').agg({
        'decimalLatitude': lambda x: x.notna().sum(),
        'bels_location_string': 'count'
    }).rename(columns={
        'decimalLatitude': 'coordinate_count',
        'bels_location_string': 'bels_group_rec_count'
    })
    
    # Merge stats back to original dataframe
    return df.merge(location_stats, on='bels_location_string')

# %%
def summarize_locations_by_region_v1(df):
    """
    Generates location group statistics for each state/county combination.
    /tmp/ipykernel_516747/3985458850.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
  return df.groupby(['stateProvince', 'county']).apply(get_stats).reset_index()
    """
    def get_stats(group):
        total_groups = group['bels_location_id'].nunique()
        groups_with_coords = group.groupby('bels_location_id')['coordinate_count'].first()
        
        return pd.Series({
            'total_location_groups': total_groups,
            'groups_with_coordinates': (groups_with_coords > 0).sum(),
            'groups_without_coordinates': (groups_with_coords == 0).sum()
        })
    
    return df.groupby(['stateProvince', 'county']).apply(get_stats).reset_index()

# %%
def summarize_locations_by_region_v2(df):
    """
    Generates location group statistics for each state/county combination.
    """
    def get_stats(group):
        total_groups = group['bels_location_id'].nunique()
        groups_with_coords = group.groupby('bels_location_id')['coordinate_count'].first()
        
        return pd.Series({
            'total_location_groups': total_groups,
            'groups_with_coordinates': (groups_with_coords > 0).sum(),
            'groups_without_coordinates': (groups_with_coords == 0).sum()
        })
    
    return df.groupby(['stateProvince', 'county']).apply(get_stats, include_groups=False).reset_index()

# %%
def summarize_locations_by_region(df):
    """
    Generates location group statistics for each state/county combination.
    """
    def get_stats(group):
        total_groups = group['bels_location_id'].nunique()
        groups_with_coords = group.groupby('bels_location_id')['coordinate_count'].first()
        total_records = len(group)
        
        return pd.Series({
            'total_location_groups': total_groups,
            'groups_with_coordinates': (groups_with_coords > 0).sum(),
            'groups_without_coordinates': (groups_with_coords == 0).sum(),
            'total_records': total_records
        })
    
    return df.groupby(['stateProvince', 'county']).apply(get_stats, include_groups=False).reset_index()

# %%
# Example usage
if __name__ == "__main__":
    # Input DataFrame
    df_occ = pd.read_csv('torch_bels_locs_SAMPLE.tsv', low_memory=False, sep='\t')
    
    # Process the DataFrame
    #result = add_coordinate_counts(data)
    result = analyze_locations(df_occ)
    
    # Display all columns
    pd.set_option('display.max_columns', None)
    print("\nProcessed DataFrame with coordinate counts:")
    print(result)
# Out:
# Processed DataFrame with coordinate counts:
#       Unnamed: 0                                    id institutionCode  \
# 0         890363                              32169803             CSU
# 1         123678                              26792115            BRIT
# 2         419345                               8774006            SRSC
# 3          80310                              24845952            BRIT
# 4         147243                              26816060             SMU
# ...          ...                                   ...             ...
# 9995      718090  e1bd18a5-13a0-4cfc-8086-a2dd72cf525a             TEX
# 9996      100960                              24932632            BRIT
# 9997      574179                              26647152             OKL
# 9998      643238                              26591222             OKL
# 9999      669058  c989068e-cf28-4b58-a0c2-9b7613367b56             TEX
#
#      collectionCode ownerInstitutionCode  \
# 0               NaN                  NaN
# 1              BRIT                  NaN
# 2               NaN                  NaN
# 3               SMU                  NaN
# 4              BRIT                  NaN
# ...             ...                  ...
# 9995            TEX                  NaN
# 9996           BRIT                  NaN
# 9997            NaN                  OKL
# 9998            NaN                  OKL
# 9999            TEX                  NaN
#
#                               collectionID      basisOfRecord  \
# 0     871cbe2c-c361-4cdb-9c3a-75a7a4ce5669  PreservedSpecimen
# 1     fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# 2     b18db63b-13de-4aa8-b16a-615f312e66df  PreservedSpecimen
# 3     fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# 4     fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# ...                                    ...                ...
# 9995                                   NaN  PreservedSpecimen
# 9996  fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# 9997  ee375191-fabb-4bc6-8180-ede944cd1edf  PreservedSpecimen
# 9998  ee375191-fabb-4bc6-8180-ede944cd1edf  PreservedSpecimen
# 9999                                   NaN  PreservedSpecimen
#
#                               occurrenceID catalogNumber otherCatalogNumbers  \
# 0     385fb31a-fc8c-11e7-8e1c-e3cf2f9a05b7           NaN             CSU5504
# 1     40939571-993a-456e-964c-0f39a2f6f092    BRIT413097                 NaN
# 2     3b049768-988f-4b3b-9719-3ba6980f956d      00001874                 NaN
# 3     b3cd1a98-bf27-45d1-a7f7-99cc39838817    BRIT360272                 NaN
# 4     de72884c-4b98-451d-b977-52043bb0d77c    BRIT411756                 NaN
# ...                                    ...           ...                 ...
# 9995  e1bd18a5-13a0-4cfc-8086-a2dd72cf525a   TEX00296496                 NaN
# 9996  543656ef-e2a2-4d08-86ec-fcd645af7edf    BRIT388547                 NaN
# 9997  177737fc-6915-4d37-9cd1-faeee5ef1c51           NaN           OKL250893
# 9998  03e521e3-df6f-4a3a-ab44-d1c560335a27           NaN          DA-OKW-225
# 9999  c989068e-cf28-4b58-a0c2-9b7613367b56   TEX00006888                 NaN
#
#              family            scientificName  taxonID  \
# 0         Lamiaceae  Physostegia angustifolia  95415.0
# 1           Poaceae     Erioneuron pulchellum   8502.0
# 2     Euphorbiaceae     Euphorbia cinerascens  45590.0
# 3      Boraginaceae    Nemophila phacelioides  92516.0
# 4           Poaceae               Briza minor    643.0
# ...             ...                       ...      ...
# 9995  Amaranthaceae     Atriplex matamorensis      NaN
# 9996   Polygalaceae        Polygala incarnata  96229.0
# 9997        Poaceae        Pascopyrum smithii   1665.0
# 9998     Asteraceae             Arctium minus   2768.0
# 9999     Asteraceae  Arnoglossum plantagineum      NaN
#
#              scientificNameAuthorship        genus  subgenus specificEpithet  \
# 0                             Fernald  Physostegia       NaN    angustifolia
# 1                     (Kunth) Tateoka   Erioneuron       NaN      pulchellum
# 2                    Engelm. in Torr.    Euphorbia       NaN     cinerascens
# 3                               Nutt.    Nemophila       NaN    phacelioides
# 4                                  L.        Briza       NaN           minor
# ...                               ...          ...       ...             ...
# 9995                              NaN     Atriplex       NaN    matamorensis
# 9996                               L.     Polygala       NaN       incarnata
# 9997  (Rydb.) Barkworth & D. R. Dewey   Pascopyrum       NaN         smithii
# 9998                    (Hill) Bernh.      Arctium       NaN           minus
# 9999                              NaN  Arnoglossum       NaN    plantagineum
#
#      verbatimTaxonRank infraspecificEpithet taxonRank        identifiedBy  \
# 0                  NaN                  NaN   Species                 NaN
# 1                  NaN                  NaN   Species                 NaN
# 2                  NaN                  NaN   Species                 NaN
# 3                  NaN                  NaN   Species                 NaN
# 4                  NaN                  NaN   Species                 NaN
# ...                ...                  ...       ...                 ...
# 9995               NaN                  NaN   Species  Turner, Billie Lee
# 9996               NaN                  NaN   Species                 NaN
# 9997               NaN                  NaN   Species         C. A. Morse
# 9998               NaN                  NaN   Species          Amy Buthod
# 9999               NaN                  NaN   Species  Turner, Billie Lee
#
#      dateIdentified                  recordedBy recordNumber   eventDate  \
# 0               NaN                 M. Hamilton    78 (2of2)  1994-06-18
# 1               NaN             Toney M. Keeney         9043  1989-05-06
# 2               NaN                         NaN          NaN         NaN
# 3               NaN               Fred B. Jones        1735A  1958-04-04
# 4               NaN                J. F. Hennen          393  1949-05-15
# ...             ...                         ...          ...         ...
# 9995           2000               Robert Runyon         1528  1933-05-01
# 9996            NaN                J. Reverchon         1906  1900-06-13
# 9997     2001-05-30  C. A. Morse; C. C. Freeman         6159  2001-05-30
# 9998     2017-07-12  Amy Buthod; Bruce Hoagland      OKW-225  2017-07-12
# 9999           2000               Mary S. Young         s.n.  1914-04-20
#
#         year  month   day  startDayOfYear  endDayOfYear verbatimEventDate  \
# 0     1994.0    6.0  18.0           169.0           NaN               NaN
# 1     1989.0    5.0   6.0           126.0           NaN        6 May 1989
# 2        NaN    NaN   NaN             NaN           NaN               NaN
# 3     1958.0    4.0   4.0            94.0           NaN          1958-4-4
# 4     1949.0    5.0  15.0           135.0           NaN      May 15, 1949
# ...      ...    ...   ...             ...           ...               ...
# 9995  1933.0    5.0   1.0             NaN           NaN               NaN
# 9996  1900.0    6.0  13.0           164.0           NaN      13 June 1900
# 9997  2001.0    5.0  30.0           150.0           NaN               NaN
# 9998  2017.0    7.0  12.0           193.0           NaN               NaN
# 9999  1914.0    4.0  20.0             NaN           NaN               NaN
#
#                                       occurrenceRemarks  \
# 0         terminal spike loosely flowered; white petals
# 1                                                   NaN
# 2                                                   NaN
# 3     In semi-shade. Rare.; Flowers light violet. St...
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                                 habitat  \
# 0                                       prairie habitat
# 1                                                   NaN
# 2                                                   NaN
# 3                          Sandy loam or alluvial soil.
# 4                                                   NaN
# ...                                                 ...
# 9995  Erect straight herb, leafy and pale green. Soi...
# 9996                                              Sands
# 9997  Eroded, rocky slopes on divide between Broken ...
# 9998                                                NaN
# 9999                                                NaN
#
#                                   associatedOccurrences  locationID  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     herbariumSpecimenDuplicate: https://portal.tor...         NaN
# ...                                                 ...         ...
# 9995                                                NaN         NaN
# 9996                                                NaN         NaN
# 9997  herbariumSpecimenDuplicate: https://portal.tor...         NaN
# 9998                                                NaN         NaN
# 9999                                                NaN         NaN
#
#             country stateProvince        county municipality  \
# 0     United States      Oklahoma        Rogers          NaN
# 1     United States         Texas        Kinney          NaN
# 2               USA         Texas      Brewster          NaN
# 3     United States         Texas  San Patricio          NaN
# 4     United States         Texas         Smith          NaN
# ...             ...           ...           ...          ...
# 9995  United States         Texas       Cameron          NaN
# 9996  United States         Texas          Wood          NaN
# 9997  United States      Oklahoma   Roger Mills          NaN
# 9998  United States      Oklahoma      Johnston          NaN
# 9999  United States         Texas       Liberty          NaN
#
#                                                locality locationRemarks  \
# 0     Ramona; 6 mi E of Ramona on road 403 between r...             NaN
# 1     On the west slopes of the mountain east of the...             NaN
# 2                                                   NaN             NaN
# 3     About 10 miles north-east of Sinton on Welder ...             NaN
# 4     Tyler State Park (10 miles north of Tyler); at...             NaN
# ...                                                 ...             ...
# 9995                           On clay dune near coast.             NaN
# 9996                                            Mineola             NaN
# 9997  Cheyenne; 2.75 mi S, 0.75 mi W of Cheyenne, Th...             NaN
# 9998  The Nature Conservancy's Oka' Yanahli Preserve...             NaN
# 9999                                              Dolen             NaN
#
#       decimalLatitude  decimalLongitude geodeticDatum  \
# 0           36.371597        -95.604379           NaN
# 1                 NaN               NaN           NaN
# 2                 NaN               NaN           NaN
# 3                 NaN               NaN           NaN
# 4                 NaN               NaN           NaN
# ...               ...               ...           ...
# 9995              NaN               NaN           NaN
# 9996              NaN               NaN           NaN
# 9997        35.588300        -99.793400           NaN
# 9998        34.441200        -96.644600           NaN
# 9999              NaN               NaN           NaN
#
#       coordinateUncertaintyInMeters  \
# 0                            5000.0
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 9995                            NaN
# 9996                            NaN
# 9997                         1609.0
# 9998                         1609.0
# 9999                            NaN
#
#                                     verbatimCoordinates georeferencedBy  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 9995                                                NaN             NaN
# 9996                                                NaN             NaN
# 9997  13N 24W 19 S/2 of SW/4; T13N R24W sec19.0 S/2 ...             NaN
# 9998                          1S 6E 26; T1S R6E sec26.0             NaN
# 9999                                                NaN             NaN
#
#      georeferenceProtocol georeferenceSources georeferenceVerificationStatus  \
# 0                     NaN                 NaN                          False
# 1                     NaN                 NaN                            NaN
# 2                     NaN                 NaN                            NaN
# 3                     NaN                 NaN                            NaN
# 4                     NaN                 NaN                            NaN
# ...                   ...                 ...                            ...
# 9995                  NaN                 NaN                            NaN
# 9996                  NaN                 NaN                            NaN
# 9997                  NaN                 NaN                          False
# 9998                  NaN                 NaN                          False
# 9999                  NaN                 NaN                            NaN
#
#                                     georeferenceRemarks  \
# 0     Needs to be georeferenced. Coordinates based o...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                  Coordinates based on TRS centroid
# 9998                  Coordinates based on TRS centroid
# 9999                                                NaN
#
#       minimumElevationInMeters  maximumElevationInMeters  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 9995                       NaN                       NaN
# 9996                       NaN                       NaN
# 9997                       NaN                       NaN
# 9998                       NaN                       NaN
# 9999                       NaN                       NaN
#
#       minimumDepthInMeters  maximumDepthInMeters  verbatimDepth  \
# 0                      NaN                   NaN            NaN
# 1                      NaN                   NaN            NaN
# 2                      NaN                   NaN            NaN
# 3                      NaN                   NaN            NaN
# 4                      NaN                   NaN            NaN
# ...                    ...                   ...            ...
# 9995                   NaN                   NaN            NaN
# 9996                   NaN                   NaN            NaN
# 9997                   NaN                   NaN            NaN
# 9998                   NaN                   NaN            NaN
# 9999                   NaN                   NaN            NaN
#
#      verbatimElevation     disposition language  recordEnteredBy  \
# 0                  NaN             NaN      NaN       VCK (OVPD)
# 1                  NaN  nfn:2021-12-07      NaN              NaN
# 2                  NaN             NaN      NaN              NaN
# 3                  NaN             NaN      NaN  TEX4BRITleg2572
# 4                  NaN    TORCH-NfN-30      NaN              NaN
# ...                ...             ...      ...              ...
# 9995               NaN             NaN      NaN              NaN
# 9996               NaN      nfn:britjb      NaN     preprocessed
# 9997               NaN             NaN      NaN              JAM
# 9998               NaN             NaN      NaN              TDF
# 9999               NaN             NaN      NaN              NaN
#
#                  modified                                         references  \
# 0     2021-03-30 00:00:00  https://portal.torcherbaria.org/portal/collect...
# 1     2023-07-16 07:02:03  https://portal.torcherbaria.org/portal/collect...
# 2     2023-07-16 07:02:03  https://portal.torcherbaria.org/portal/collect...
# 3     2020-07-15 10:57:06  https://portal.torcherbaria.org/portal/collect...
# 4     2024-10-29 08:00:38  https://portal.torcherbaria.org/portal/collect...
# ...                   ...                                                ...
# 9995                  NaN                                                NaN
# 9996  2023-07-16 07:02:03  https://portal.torcherbaria.org/portal/collect...
# 9997  2010-01-20 00:00:00  https://portal.torcherbaria.org/portal/collect...
# 9998  2019-08-22 00:00:00  https://portal.torcherbaria.org/portal/collect...
# 9999                  NaN                                                NaN
#
#                                    bels_location_string  bels_location_id  \
# 0     oklahomarogersramona6mieoframonaonroad403betwe...                 0
# 1     texaskinneyonthewestslopesofthemountaineastoft...                 1
# 2                                         texasbrewster                 2
# 3     texassanpatricioabout10milesnortheastofsintono...                 3
# 4     texassmithtylerstatepark10milesnorthoftylerate...                 4
# ...                                                 ...               ...
# 9995                    texascamerononclaydunenearcoast              8379
# 9996                                   texaswoodmineola              4510
# 9997  oklahomarogermillscheyenne2.75mis0.75miwofchey...              7296
# 9998  oklahomajohnstonthenatureconservancy'soka'yana...              5008
# 9999                                  texaslibertydolen              8380
#
#       coordinate_count  bels_group_rec_count
# 0                    1                     1
# 1                    0                     1
# 2                    0                   110
# 3                    0                     1
# 4                    0                     1
# ...                ...                   ...
# 9995                 0                     1
# 9996                 0                     2
# 9997                 2                     2
# 9998                 1                     2
# 9999                 0                     1
#
# [10000 rows x 66 columns]

# %%
result
#df_sorted = result.sort_values(by=['coordinate_count'], ascending=False)
#df_sorted
# Out:
#       Unnamed: 0                                    id institutionCode  \
# 0         890363                              32169803             CSU
# 1         123678                              26792115            BRIT
# 2         419345                               8774006            SRSC
# 3          80310                              24845952            BRIT
# 4         147243                              26816060             SMU
# ...          ...                                   ...             ...
# 9995      718090  e1bd18a5-13a0-4cfc-8086-a2dd72cf525a             TEX
# 9996      100960                              24932632            BRIT
# 9997      574179                              26647152             OKL
# 9998      643238                              26591222             OKL
# 9999      669058  c989068e-cf28-4b58-a0c2-9b7613367b56             TEX
#
#      collectionCode ownerInstitutionCode  \
# 0               NaN                  NaN
# 1              BRIT                  NaN
# 2               NaN                  NaN
# 3               SMU                  NaN
# 4              BRIT                  NaN
# ...             ...                  ...
# 9995            TEX                  NaN
# 9996           BRIT                  NaN
# 9997            NaN                  OKL
# 9998            NaN                  OKL
# 9999            TEX                  NaN
#
#                               collectionID      basisOfRecord  \
# 0     871cbe2c-c361-4cdb-9c3a-75a7a4ce5669  PreservedSpecimen
# 1     fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# 2     b18db63b-13de-4aa8-b16a-615f312e66df  PreservedSpecimen
# 3     fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# 4     fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# ...                                    ...                ...
# 9995                                   NaN  PreservedSpecimen
# 9996  fea81a47-2365-45cc-bef9-b6bbff7457e6  PreservedSpecimen
# 9997  ee375191-fabb-4bc6-8180-ede944cd1edf  PreservedSpecimen
# 9998  ee375191-fabb-4bc6-8180-ede944cd1edf  PreservedSpecimen
# 9999                                   NaN  PreservedSpecimen
#
#                               occurrenceID catalogNumber otherCatalogNumbers  \
# 0     385fb31a-fc8c-11e7-8e1c-e3cf2f9a05b7           NaN             CSU5504
# 1     40939571-993a-456e-964c-0f39a2f6f092    BRIT413097                 NaN
# 2     3b049768-988f-4b3b-9719-3ba6980f956d      00001874                 NaN
# 3     b3cd1a98-bf27-45d1-a7f7-99cc39838817    BRIT360272                 NaN
# 4     de72884c-4b98-451d-b977-52043bb0d77c    BRIT411756                 NaN
# ...                                    ...           ...                 ...
# 9995  e1bd18a5-13a0-4cfc-8086-a2dd72cf525a   TEX00296496                 NaN
# 9996  543656ef-e2a2-4d08-86ec-fcd645af7edf    BRIT388547                 NaN
# 9997  177737fc-6915-4d37-9cd1-faeee5ef1c51           NaN           OKL250893
# 9998  03e521e3-df6f-4a3a-ab44-d1c560335a27           NaN          DA-OKW-225
# 9999  c989068e-cf28-4b58-a0c2-9b7613367b56   TEX00006888                 NaN
#
#              family            scientificName  taxonID  \
# 0         Lamiaceae  Physostegia angustifolia  95415.0
# 1           Poaceae     Erioneuron pulchellum   8502.0
# 2     Euphorbiaceae     Euphorbia cinerascens  45590.0
# 3      Boraginaceae    Nemophila phacelioides  92516.0
# 4           Poaceae               Briza minor    643.0
# ...             ...                       ...      ...
# 9995  Amaranthaceae     Atriplex matamorensis      NaN
# 9996   Polygalaceae        Polygala incarnata  96229.0
# 9997        Poaceae        Pascopyrum smithii   1665.0
# 9998     Asteraceae             Arctium minus   2768.0
# 9999     Asteraceae  Arnoglossum plantagineum      NaN
#
#              scientificNameAuthorship        genus  subgenus specificEpithet  \
# 0                             Fernald  Physostegia       NaN    angustifolia
# 1                     (Kunth) Tateoka   Erioneuron       NaN      pulchellum
# 2                    Engelm. in Torr.    Euphorbia       NaN     cinerascens
# 3                               Nutt.    Nemophila       NaN    phacelioides
# 4                                  L.        Briza       NaN           minor
# ...                               ...          ...       ...             ...
# 9995                              NaN     Atriplex       NaN    matamorensis
# 9996                               L.     Polygala       NaN       incarnata
# 9997  (Rydb.) Barkworth & D. R. Dewey   Pascopyrum       NaN         smithii
# 9998                    (Hill) Bernh.      Arctium       NaN           minus
# 9999                              NaN  Arnoglossum       NaN    plantagineum
#
#      verbatimTaxonRank infraspecificEpithet taxonRank        identifiedBy  \
# 0                  NaN                  NaN   Species                 NaN
# 1                  NaN                  NaN   Species                 NaN
# 2                  NaN                  NaN   Species                 NaN
# 3                  NaN                  NaN   Species                 NaN
# 4                  NaN                  NaN   Species                 NaN
# ...                ...                  ...       ...                 ...
# 9995               NaN                  NaN   Species  Turner, Billie Lee
# 9996               NaN                  NaN   Species                 NaN
# 9997               NaN                  NaN   Species         C. A. Morse
# 9998               NaN                  NaN   Species          Amy Buthod
# 9999               NaN                  NaN   Species  Turner, Billie Lee
#
#      dateIdentified                  recordedBy recordNumber   eventDate  \
# 0               NaN                 M. Hamilton    78 (2of2)  1994-06-18
# 1               NaN             Toney M. Keeney         9043  1989-05-06
# 2               NaN                         NaN          NaN         NaN
# 3               NaN               Fred B. Jones        1735A  1958-04-04
# 4               NaN                J. F. Hennen          393  1949-05-15
# ...             ...                         ...          ...         ...
# 9995           2000               Robert Runyon         1528  1933-05-01
# 9996            NaN                J. Reverchon         1906  1900-06-13
# 9997     2001-05-30  C. A. Morse; C. C. Freeman         6159  2001-05-30
# 9998     2017-07-12  Amy Buthod; Bruce Hoagland      OKW-225  2017-07-12
# 9999           2000               Mary S. Young         s.n.  1914-04-20
#
#         year  month   day  startDayOfYear  endDayOfYear verbatimEventDate  \
# 0     1994.0    6.0  18.0           169.0           NaN               NaN
# 1     1989.0    5.0   6.0           126.0           NaN        6 May 1989
# 2        NaN    NaN   NaN             NaN           NaN               NaN
# 3     1958.0    4.0   4.0            94.0           NaN          1958-4-4
# 4     1949.0    5.0  15.0           135.0           NaN      May 15, 1949
# ...      ...    ...   ...             ...           ...               ...
# 9995  1933.0    5.0   1.0             NaN           NaN               NaN
# 9996  1900.0    6.0  13.0           164.0           NaN      13 June 1900
# 9997  2001.0    5.0  30.0           150.0           NaN               NaN
# 9998  2017.0    7.0  12.0           193.0           NaN               NaN
# 9999  1914.0    4.0  20.0             NaN           NaN               NaN
#
#                                       occurrenceRemarks  \
# 0         terminal spike loosely flowered; white petals
# 1                                                   NaN
# 2                                                   NaN
# 3     In semi-shade. Rare.; Flowers light violet. St...
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                                 habitat  \
# 0                                       prairie habitat
# 1                                                   NaN
# 2                                                   NaN
# 3                          Sandy loam or alluvial soil.
# 4                                                   NaN
# ...                                                 ...
# 9995  Erect straight herb, leafy and pale green. Soi...
# 9996                                              Sands
# 9997  Eroded, rocky slopes on divide between Broken ...
# 9998                                                NaN
# 9999                                                NaN
#
#                                   associatedOccurrences  locationID  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     herbariumSpecimenDuplicate: https://portal.tor...         NaN
# ...                                                 ...         ...
# 9995                                                NaN         NaN
# 9996                                                NaN         NaN
# 9997  herbariumSpecimenDuplicate: https://portal.tor...         NaN
# 9998                                                NaN         NaN
# 9999                                                NaN         NaN
#
#             country stateProvince        county municipality  \
# 0     United States      Oklahoma        Rogers          NaN
# 1     United States         Texas        Kinney          NaN
# 2               USA         Texas      Brewster          NaN
# 3     United States         Texas  San Patricio          NaN
# 4     United States         Texas         Smith          NaN
# ...             ...           ...           ...          ...
# 9995  United States         Texas       Cameron          NaN
# 9996  United States         Texas          Wood          NaN
# 9997  United States      Oklahoma   Roger Mills          NaN
# 9998  United States      Oklahoma      Johnston          NaN
# 9999  United States         Texas       Liberty          NaN
#
#                                                locality locationRemarks  \
# 0     Ramona; 6 mi E of Ramona on road 403 between r...             NaN
# 1     On the west slopes of the mountain east of the...             NaN
# 2                                                   NaN             NaN
# 3     About 10 miles north-east of Sinton on Welder ...             NaN
# 4     Tyler State Park (10 miles north of Tyler); at...             NaN
# ...                                                 ...             ...
# 9995                           On clay dune near coast.             NaN
# 9996                                            Mineola             NaN
# 9997  Cheyenne; 2.75 mi S, 0.75 mi W of Cheyenne, Th...             NaN
# 9998  The Nature Conservancy's Oka' Yanahli Preserve...             NaN
# 9999                                              Dolen             NaN
#
#       decimalLatitude  decimalLongitude geodeticDatum  \
# 0           36.371597        -95.604379           NaN
# 1                 NaN               NaN           NaN
# 2                 NaN               NaN           NaN
# 3                 NaN               NaN           NaN
# 4                 NaN               NaN           NaN
# ...               ...               ...           ...
# 9995              NaN               NaN           NaN
# 9996              NaN               NaN           NaN
# 9997        35.588300        -99.793400           NaN
# 9998        34.441200        -96.644600           NaN
# 9999              NaN               NaN           NaN
#
#       coordinateUncertaintyInMeters  \
# 0                            5000.0
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 9995                            NaN
# 9996                            NaN
# 9997                         1609.0
# 9998                         1609.0
# 9999                            NaN
#
#                                     verbatimCoordinates georeferencedBy  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 9995                                                NaN             NaN
# 9996                                                NaN             NaN
# 9997  13N 24W 19 S/2 of SW/4; T13N R24W sec19.0 S/2 ...             NaN
# 9998                          1S 6E 26; T1S R6E sec26.0             NaN
# 9999                                                NaN             NaN
#
#      georeferenceProtocol georeferenceSources georeferenceVerificationStatus  \
# 0                     NaN                 NaN                          False
# 1                     NaN                 NaN                            NaN
# 2                     NaN                 NaN                            NaN
# 3                     NaN                 NaN                            NaN
# 4                     NaN                 NaN                            NaN
# ...                   ...                 ...                            ...
# 9995                  NaN                 NaN                            NaN
# 9996                  NaN                 NaN                            NaN
# 9997                  NaN                 NaN                          False
# 9998                  NaN                 NaN                          False
# 9999                  NaN                 NaN                            NaN
#
#                                     georeferenceRemarks  \
# 0     Needs to be georeferenced. Coordinates based o...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                  Coordinates based on TRS centroid
# 9998                  Coordinates based on TRS centroid
# 9999                                                NaN
#
#       minimumElevationInMeters  maximumElevationInMeters  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 9995                       NaN                       NaN
# 9996                       NaN                       NaN
# 9997                       NaN                       NaN
# 9998                       NaN                       NaN
# 9999                       NaN                       NaN
#
#       minimumDepthInMeters  maximumDepthInMeters  verbatimDepth  \
# 0                      NaN                   NaN            NaN
# 1                      NaN                   NaN            NaN
# 2                      NaN                   NaN            NaN
# 3                      NaN                   NaN            NaN
# 4                      NaN                   NaN            NaN
# ...                    ...                   ...            ...
# 9995                   NaN                   NaN            NaN
# 9996                   NaN                   NaN            NaN
# 9997                   NaN                   NaN            NaN
# 9998                   NaN                   NaN            NaN
# 9999                   NaN                   NaN            NaN
#
#      verbatimElevation     disposition language  recordEnteredBy  \
# 0                  NaN             NaN      NaN       VCK (OVPD)
# 1                  NaN  nfn:2021-12-07      NaN              NaN
# 2                  NaN             NaN      NaN              NaN
# 3                  NaN             NaN      NaN  TEX4BRITleg2572
# 4                  NaN    TORCH-NfN-30      NaN              NaN
# ...                ...             ...      ...              ...
# 9995               NaN             NaN      NaN              NaN
# 9996               NaN      nfn:britjb      NaN     preprocessed
# 9997               NaN             NaN      NaN              JAM
# 9998               NaN             NaN      NaN              TDF
# 9999               NaN             NaN      NaN              NaN
#
#                  modified                                         references  \
# 0     2021-03-30 00:00:00  https://portal.torcherbaria.org/portal/collect...
# 1     2023-07-16 07:02:03  https://portal.torcherbaria.org/portal/collect...
# 2     2023-07-16 07:02:03  https://portal.torcherbaria.org/portal/collect...
# 3     2020-07-15 10:57:06  https://portal.torcherbaria.org/portal/collect...
# 4     2024-10-29 08:00:38  https://portal.torcherbaria.org/portal/collect...
# ...                   ...                                                ...
# 9995                  NaN                                                NaN
# 9996  2023-07-16 07:02:03  https://portal.torcherbaria.org/portal/collect...
# 9997  2010-01-20 00:00:00  https://portal.torcherbaria.org/portal/collect...
# 9998  2019-08-22 00:00:00  https://portal.torcherbaria.org/portal/collect...
# 9999                  NaN                                                NaN
#
#                                    bels_location_string  bels_location_id  \
# 0     oklahomarogersramona6mieoframonaonroad403betwe...                 0
# 1     texaskinneyonthewestslopesofthemountaineastoft...                 1
# 2                                         texasbrewster                 2
# 3     texassanpatricioabout10milesnortheastofsintono...                 3
# 4     texassmithtylerstatepark10milesnorthoftylerate...                 4
# ...                                                 ...               ...
# 9995                    texascamerononclaydunenearcoast              8379
# 9996                                   texaswoodmineola              4510
# 9997  oklahomarogermillscheyenne2.75mis0.75miwofchey...              7296
# 9998  oklahomajohnstonthenatureconservancy'soka'yana...              5008
# 9999                                  texaslibertydolen              8380
#
#       coordinate_count  bels_group_rec_count
# 0                    1                     1
# 1                    0                     1
# 2                    0                   110
# 3                    0                     1
# 4                    0                     1
# ...                ...                   ...
# 9995                 0                     1
# 9996                 0                     2
# 9997                 2                     2
# 9998                 1                     2
# 9999                 0                     1
#
# [10000 rows x 66 columns]

# %% [raw]
# # After running analyze_locations
# print(result.columns)  # This will show all column names
# #print(columns[['bels_location_string', 'bels_location_id', 'bels_group_rec_count']].head())  # Show sample data

# %% [raw]
# result

# %%
df_summary = summarize_locations_by_region(result)

# %%
df_summary
# Out:
#     stateProvince      county  total_location_groups  groups_with_coordinates  \
# 0        Oklahoma       Adair                     35                       16
# 1        Oklahoma     Alfalfa                     11                        7
# 2        Oklahoma       Atoka                     37                       18
# 3        Oklahoma      Beaver                     10                        8
# 4        Oklahoma     Beckham                      9                        5
# ..            ...         ...                    ...                      ...
# 393         Texas      Yoakum                      2                        0
# 394         Texas       Young                      3                        2
# 395         Texas      Zapata                     16                        7
# 396         Texas      Zavala                      4                        1
# 397         Texas  not listed                      4                        0
#
#      groups_without_coordinates  total_records
# 0                            19             38
# 1                             4             11
# 2                            19             41
# 3                             2             10
# 4                             4             13
# ..                          ...            ...
# 393                           2              3
# 394                           1              3
# 395                           9             17
# 396                           3              4
# 397                           4              6
#
# [398 rows x 6 columns]
